# %%
#!/usr/bin/env python
# coding: utf-8

from Bio import Entrez
from Bio import Medline

##########################
#      module clean      #
##########################

def clean_data(x):
    chaine = str(x)
    chaine = chaine.replace("['"," ")
    chaine = chaine.replace("']"," ")
    chaine = chaine.replace("'"," ")
    return chaine


def clean_a(x):
    chaine = str(x)
    chaine = chaine.replace("/","")
    chaine = chaine.replace("*"," ")
    return chaine

def clean_date(x):
    import datetime
    md = datetime.datetime.strptime(x,"%Y%m%d").date()
    return md

###########################
#    connexion à PubMed   #
###########################

def ConPub():
    Entrez.api_key = "41843b992ded592334c39fe437c425e40608"
    Entrez.email = "sacha.torres@univ_montp3.fr"
    Entrez.tool = "Inca"
    print("connexion active !!!  Captain Picard from Enterprise-F")
    
###########################
#   module query          #
###########################

def Query():
    p = input("query pubmed :")
    pq = p + " "+"and Cochrane Database Syst Rev"
    return pq

def CorQuPub(q):
    han = Entrez.espell(term=q)
    rea = Entrez.read(han)
    return rea["CorrectedQuery"]
    
###########################
#  module Meta Cochrane   #
###########################
    
def MetaList(q):
    hend = Entrez.esearch(db="pubmed",term=q)
    ret = Entrez.read(hend)
    return ret["IdList"]

def MetaCount(q):
    hand = Entrez.esearch(db="pubmed",term=q)
    rec = Entrez.read(hand)
    return rec["Count"]    
   

###################################
#  affichage trials list by meta  #
###################################

def FetchIdList(ids):
    handle = Entrez.efetch(db="pubmed",id=ids,rettype="medline",retmode="text")
    record = Medline.parse(handle)
    return record


###########################
#  affichage datas metas  #
########################### 

def DatasFromIds(idlist):
    for res in idlist:
        print("Title : ",res["TI"])
        print("PMID : ",res["PMID"]+", ",end="")
        print("NLM identifier : ",res["JID"]+", ",end="")
        # catch error if no OID exist
        try:
            print("other identifier : ",res["OID"],end="")
        except KeyError :
            print("Other identifier : none ")
        # return all authors    
        r = clean_data(res["FAU"])
        print("Authors : ",r)
        # return MesH terms list
        mh = clean_data(res["MH"])
        print("MesH terms:")
        print(mh)
        # catch error if no OT exist
        try :
            print("Key Words: ",res["OT"])
        except KeyError:
            print("Key Words: none ")    
        # catch error if no source exist
        try:
            print("Publication source :","  ",res["SO"]) 
        except KeyError:
            print("Publication source : none")
        # return create date from pubmed   
        dt = clean_data(res["CRDT"])    
        print("Create Date : ",dt)
        # return revision date from pubmed
        revdt = clean_date(res["LR"])
        print("Revision Date :",revdt)
        print(" ")
        



        
        
        
# main ------------------------------------
ConPub()
a = Query()
g = CorQuPub(a) 
print("modified MeSH Terms query : ",g)
print("")
b = MetaList(g)
c = MetaCount(g)
print(" nb metas : ",c)
print(" ")
y = FetchIdList(b)
DatasFromIds(y)
# Out:
# connexion active !!!  Captain Picard from Enterprise-F
# query pubmed :green tea and neoplamssm
# modified MeSH Terms query :  green tea and neoplasms and cochrane database syst rev
#
#  nb metas :  6
#
# Key Words: none
# Publication source :    Cochrane Database Syst Rev. 2006 Oct 18;(4):CD001829. doi: 10.1002/14651858.CD001829.pub3.
# Create Date :   2006/10/21 09:00
# Revision Date : 2019-06-22
#
# Title :  Interventions for treating oral leukoplakia.
# PMID :  15266454, NLM identifier :  100909747, Other identifier : none
# Authors :   Lodi, G ,  Sardella, A ,  Bez, C ,  Demarosi, F ,  Carrassi, A
# MesH terms:
#  Humans ,  Leukoplakia, Oral/*therapy ,  Randomized Controlled Trials as Topic
# Key Words: none
# Publication source :    Cochrane Database Syst Rev. 2004;(3):CD001829. doi: 10.1002/14651858.CD001829.pub2.
# Create Date :   2004/07/22 05:00
# Revision Date : 2019-06-22
#
# Title :  Interventions for treating oral leukoplakia.
# PMID :  11687126, NLM identifier :  100909747, Other identifier : none
# Authors :   Lodi, G ,  Sardella, A ,  Bez, C ,  Demarosi, F ,  Carrassi, A
# MesH terms:
#  Humans ,  Leukoplakia, Oral/*therapy ,  Randomized Controlled Trials as Topic
# Key Words: none
# Publication source :    Cochrane Database Syst Rev. 2001;(4):CD001829. doi: 10.1002/14651858.CD001829.
# Create Date :   2001/11/01 10:00
# Revision Date : 2018-12-21

# %%
#!/usr/bin/env python
# coding: utf-8

from Bio import Entrez
from Bio import Medline

##########################
#      module clean      #
##########################

def clean_data(x):
    chaine = str(x)
    chaine = chaine.replace("['"," ")
    chaine = chaine.replace("']"," ")
    chaine = chaine.replace("'"," ")
    return chaine


def clean_a(x):
    chaine = str(x)
    chaine = chaine.replace("/","")
    chaine = chaine.replace("*"," ")
    return chaine

def clean_date(x):
    import datetime
    md = datetime.datetime.strptime(x,"%Y%m%d").date()
    return md

###########################
#    connexion à PubMed   #
###########################

def ConPub():
    Entrez.api_key = "41843b992ded592334c39fe437c425e40608"
    Entrez.email = "sacha.torres@univ_montp3.fr"
    Entrez.tool = "Inca"
    print("connexion active !!!  Captain Picard from Enterprise-F")
    
###########################
#   module query          #
###########################

def Query():
    p = input("query pubmed :")
    pq = p + " "+"and Cochrane Database Syst Rev"
    return pq

def CorQuPub(q):
    han = Entrez.espell(term=q)
    rea = Entrez.read(han)
    return rea["CorrectedQuery"]
    
###########################
#  module Meta Cochrane   #
###########################
    
def MetaList(q):
    hend = Entrez.esearch(db="pubmed",term=q)
    ret = Entrez.read(hend)
    return ret["IdList"]

def MetaCount(q):
    hand = Entrez.esearch(db="pubmed",term=q)
    rec = Entrez.read(hand)
    return rec["Count"]    
   

###################################
#  affichage trials stats by DBs  #
###################################

def FetchIdList(ids):
    handle = Entrez.efetch(db="pubmed",id=ids,rettype="medline",retmode="text")
    record = Medline.parse(handle)
    return record
# input : pmid list from MetaList()    output : dictionnaire stats 
def TrLs(pid):
    hind = Entrez.elink(db="pubmed",id=pid,cmd="neighbor_score")
    rec = Entrez.read(hind)
    return rec
# input  : result from TrLs(pid) a integer from Metacount()  output : print stats links by db  , link by pmid

def PubStatsLinks(result,a):
    ide = clean_data(result[a]["IdList"])
    print("pmid de la publication Cochrane: ",ide)
    cpl = 0
    for link in result[a]["LinkSetDb"]:
        cpl = cpl + 1
        print("nom du lien de cette publication dans pubmed ",link["LinkName"]," numéro du lien :",cpl)
        print("nombre de publications lié à cette publication Cochrane ",ide," dans ",link["LinkName"],": ",len(link["Link"]))

        
        print("-------------------------------------------------------------------------------")
    print(" nombre de liens concernés par cette publication :",cpl)    

def PubLinkFetch():
    pass
    
 # main ------------------------------------
ConPub()
a = Query()
g = CorQuPub(a) 
print("modified MeSH Terms query : ",g)
print("")
b = MetaList(g)
print("liste des publications Cochrane correspondant à la requête : \n",b)
c = MetaCount(g)
print(" nombre de publications Cochrane correspondant à la requête : ",c)
print(" ")
y = TrLs(b)
#print(y)
try :
    for i in range(0,int(c)):
        PubStatsLinks(y,i)
        print(" ")    
except IndexError :
    print(" Fin des liens concernés dans pubmed")
    print("les liens non cités ne comporte aucune publication lié à cette liste de publication Cochrane ")
# Out:
# connexion active !!!  Captain Picard from Enterprise-F
# query pubmed :green tea and neoplsms
# modified MeSH Terms query :  green tea and neoplasms and cochrane database syst rev
#
# liste des publications Cochrane correspondant à la requête :
#  ['29360138', '27471845', '19588362', '17054142', '15266454', '11687126']
#  nombre de publications Cochrane correspondant à la requête :  6
#
# pmid de la publication Cochrane:   29360138
# nom du lien de cette publication dans pubmed  pubmed_pubmed  numéro du lien : 1
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed :  383
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_alsoviewed  numéro du lien : 2
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_alsoviewed :  11
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_citedin  numéro du lien : 3
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_citedin :  8
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_combined  numéro du lien : 4
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_combined :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_five  numéro du lien : 5
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_five :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_refs  numéro du lien : 6
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_refs :  198
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews  numéro du lien : 7
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_reviews :  152
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews_five  numéro du lien : 8
# nombre de publications lié à cette publication Cochrane   29360138   dans  pubmed_pubmed_reviews_five :  5
# -------------------------------------------------------------------------------
#  nombre de liens concernés par cette publication : 8
#
# pmid de la publication Cochrane:   27471845
# nom du lien de cette publication dans pubmed  pubmed_pubmed  numéro du lien : 1
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed :  340
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_alsoviewed  numéro du lien : 2
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_alsoviewed :  17
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_citedin  numéro du lien : 3
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_citedin :  13
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_combined  numéro du lien : 4
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_combined :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_five  numéro du lien : 5
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_five :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_refs  numéro du lien : 6
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_refs :  69
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews  numéro du lien : 7
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_reviews :  201
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews_five  numéro du lien : 8
# nombre de publications lié à cette publication Cochrane   27471845   dans  pubmed_pubmed_reviews_five :  5
# -------------------------------------------------------------------------------
#  nombre de liens concernés par cette publication : 8
#
# pmid de la publication Cochrane:   19588362
# nom du lien de cette publication dans pubmed  pubmed_pubmed  numéro du lien : 1
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed :  231
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_alsoviewed  numéro du lien : 2
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_alsoviewed :  38
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_citedin  numéro du lien : 3
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_citedin :  66
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_combined  numéro du lien : 4
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_combined :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_five  numéro du lien : 5
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_five :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_refs  numéro du lien : 6
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_refs :  129
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews  numéro du lien : 7
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_reviews :  94
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews_five  numéro du lien : 8
# nombre de publications lié à cette publication Cochrane   19588362   dans  pubmed_pubmed_reviews_five :  5
# -------------------------------------------------------------------------------
#  nombre de liens concernés par cette publication : 8
#
# pmid de la publication Cochrane:   17054142
# nom du lien de cette publication dans pubmed  pubmed_pubmed  numéro du lien : 1
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed :  101
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_alsoviewed  numéro du lien : 2
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed_alsoviewed :  10
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_citedin  numéro du lien : 3
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed_citedin :  24
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_combined  numéro du lien : 4
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed_combined :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_five  numéro du lien : 5
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed_five :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews  numéro du lien : 6
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed_reviews :  67
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews_five  numéro du lien : 7
# nombre de publications lié à cette publication Cochrane   17054142   dans  pubmed_pubmed_reviews_five :  5
# -------------------------------------------------------------------------------
#  nombre de liens concernés par cette publication : 7
#
# pmid de la publication Cochrane:   15266454
# nom du lien de cette publication dans pubmed  pubmed_pubmed  numéro du lien : 1
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed :  96
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_alsoviewed  numéro du lien : 2
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed_alsoviewed :  1
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_citedin  numéro du lien : 3
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed_citedin :  3
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_combined  numéro du lien : 4
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed_combined :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_five  numéro du lien : 5
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed_five :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews  numéro du lien : 6
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed_reviews :  65
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews_five  numéro du lien : 7
# nombre de publications lié à cette publication Cochrane   15266454   dans  pubmed_pubmed_reviews_five :  5
# -------------------------------------------------------------------------------
#  nombre de liens concernés par cette publication : 7
#
# pmid de la publication Cochrane:   11687126
# nom du lien de cette publication dans pubmed  pubmed_pubmed  numéro du lien : 1
# nombre de publications lié à cette publication Cochrane   11687126   dans  pubmed_pubmed :  67
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_citedin  numéro du lien : 2
# nombre de publications lié à cette publication Cochrane   11687126   dans  pubmed_pubmed_citedin :  1
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_combined  numéro du lien : 3
# nombre de publications lié à cette publication Cochrane   11687126   dans  pubmed_pubmed_combined :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_five  numéro du lien : 4
# nombre de publications lié à cette publication Cochrane   11687126   dans  pubmed_pubmed_five :  5
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews  numéro du lien : 5
# nombre de publications lié à cette publication Cochrane   11687126   dans  pubmed_pubmed_reviews :  47
# -------------------------------------------------------------------------------
# nom du lien de cette publication dans pubmed  pubmed_pubmed_reviews_five  numéro du lien : 6
# nombre de publications lié à cette publication Cochrane   11687126   dans  pubmed_pubmed_reviews_five :  5
# -------------------------------------------------------------------------------
#  nombre de liens concernés par cette publication : 6
